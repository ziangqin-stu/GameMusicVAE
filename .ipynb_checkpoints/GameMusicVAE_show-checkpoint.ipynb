# %% [markdown]
# ## Environment Setup
# To run this project, you should install packages listed in requirements.txt:
#
# > $ sudo pip3 install requirements.txt
#
# To take a closer look at the code, the first thing you should know is:
# 1. useful codes can be found in ./lib, all data, including any formats of midi file and models, are located in ./source.
# 2. the command-line interface of this project is ./gmvae.py, though this interface is not fully finished yet, you should consider using this as the only way to access all functionalities of this project.
#
# The rest contents are easy to explore.

# %% [markdown]
# ## Reuse MusicVAE's Model
# The first experiment is to build a game music dataset and use this domain dataset to train a standard MusicVAE. Then we will do some sampling to see if the result makes sense.
#
# ### Data Collection Pipeline
# The first data preparing step basically contain three data format(.mid, .txt, .tfrecord) and three stages:
# 1. collecting midi file from Internet (.mid);
# 2. screening and windowing raw midi files to fixed-length trio midi file (.mid -> .txt -> .mid)
# 3. transfer midi files to note sequences (.tfrecord), note sequence form can be feed into MusicVAE;
#
# The tailed pipeline of building a dataset is as follws:
# 1. collect raw midi files from "[VGMusic](https://www.vgmusic.com/)" and store them in a folder;
# 2. transform raw midi files to PrettyMIDI object (see [pretty_midi](http://craffel.github.io/pretty-midi/) and persist PrettyMIDI objects into .txt file in a batch way;
# 3. screening and windowing raw PrettyMIDI object to form trio dataset, then persist windowed PrettyMIDI objects into .txt file in a batch way, the screening and windowing method is the same as the method introduced in MuiscVAE paper "[A Hierarchical Latent Vector Model for Learning Long-Term Structure in Music](https://arxiv.org/abs/1803.05428)";
# 4. transfer trio dataset to midi files and store in a folder

# %%
# !python3 gmvae.py -p collect
# Out:
# Searching MIDI files from root URL(https://www.vgmusic.com)...
#     iter no.: 1 | 1 urls to explore | 0 midi-urls found
#     iter no.: 2 | 59 urls to explore | 0 midi-urls found
#     iter no.: 3 | 58 urls to explore | 0 midi-urls found
#     iter no.: 4 | 57 urls to explore | 4204 midi-urls found
#     iter no.: 5 | 56 urls to explore | 6237 midi-urls found
#     iter no.: 6 | 55 urls to explore | 12946 midi-urls found
#     iter no.: 7 | 54 urls to explore | 14846 midi-urls found
#     iter no.: 8 | 53 urls to explore | 14854 midi-urls found
#     iter no.: 9 | 52 urls to explore | 16621 midi-urls found
#     iter no.: 10 | 51 urls to explore | 17472 midi-urls found
#     iter no.: 11 | 50 urls to explore | 18205 midi-urls found
#     iter no.: 12 | 49 urls to explore | 18258 midi-urls found
#     iter no.: 13 | 48 urls to explore | 18763 midi-urls found
#     iter no.: 14 | 47 urls to explore | 18774 midi-urls found
#     iter no.: 15 | 46 urls to explore | 18786 midi-urls found
#     iter no.: 16 | 45 urls to explore | 20371 midi-urls found
#     iter no.: 17 | 44 urls to explore | 20527 midi-urls found
#     iter no.: 18 | 43 urls to explore | 22940 midi-urls found
#     iter no.: 19 | 42 urls to explore | 23207 midi-urls found
#     iter no.: 20 | 41 urls to explore | 23258 midi-urls found
#     iter no.: 21 | 40 urls to explore | 23698 midi-urls found
#     iter no.: 22 | 39 urls to explore | 23998 midi-urls found
#     iter no.: 23 | 38 urls to explore | 26733 midi-urls found
#     iter no.: 24 | 37 urls to explore | 27566 midi-urls found
#     iter no.: 25 | 36 urls to explore | 27598 midi-urls found
#     iter no.: 26 | 35 urls to explore | 27602 midi-urls found
#     iter no.: 27 | 34 urls to explore | 27639 midi-urls found
#     iter no.: 28 | 33 urls to explore | 27697 midi-urls found
#     iter no.: 29 | 32 urls to explore | 27751 midi-urls found
#     iter no.: 30 | 31 urls to explore | 27751 midi-urls found
#     iter no.: 31 | 30 urls to explore | 27849 midi-urls found
#     iter no.: 32 | 29 urls to explore | 27890 midi-urls found
#     iter no.: 33 | 28 urls to explore | 27891 midi-urls found
#     iter no.: 34 | 27 urls to explore | 27892 midi-urls found
#     iter no.: 35 | 26 urls to explore | 28124 midi-urls found
#     iter no.: 36 | 25 urls to explore | 28135 midi-urls found
#     iter no.: 37 | 24 urls to explore | 28448 midi-urls found
#     iter no.: 38 | 23 urls to explore | 28450 midi-urls found
#     iter no.: 39 | 22 urls to explore | 28451 midi-urls found
#     iter no.: 40 | 21 urls to explore | 28541 midi-urls found
#     iter no.: 41 | 20 urls to explore | 28547 midi-urls found
#     iter no.: 42 | 19 urls to explore | 28556 midi-urls found
#     iter no.: 43 | 18 urls to explore | 28564 midi-urls found
#     iter no.: 44 | 17 urls to explore | 28573 midi-urls found
#     iter no.: 45 | 16 urls to explore | 29294 midi-urls found
#     iter no.: 46 | 15 urls to explore | 29611 midi-urls found
#     iter no.: 47 | 14 urls to explore | 29717 midi-urls found
#     iter no.: 48 | 13 urls to explore | 29818 midi-urls found
#     iter no.: 49 | 12 urls to explore | 29971 midi-urls found
#     iter no.: 50 | 11 urls to explore | 29976 midi-urls found
#     iter no.: 51 | 10 urls to explore | 29977 midi-urls found
#     iter no.: 52 | 9 urls to explore | 29993 midi-urls found
#     iter no.: 53 | 8 urls to explore | 30006 midi-urls found
#     iter no.: 54 | 7 urls to explore | 30028 midi-urls found
#     iter no.: 55 | 6 urls to explore | 30029 midi-urls found
#     iter no.: 56 | 5 urls to explore | 30037 midi-urls found
#     iter no.: 57 | 4 urls to explore | 30042 midi-urls found
#     iter no.: 58 | 3 urls to explore | 30852 midi-urls found
#     iter no.: 59 | 2 urls to explore | 31085 midi-urls found
#     iter no.: 60 | 1 urls to explore | 31797 midi-urls found
#     # searching finished!
#
# Saving MIDI-URL list
#     # saved list at ./source/data/s_url_list.txt!
#
# Saving MIDI files...
#     no.1 | nes_10-Yard_Fight-Kick_Off.mid!
#     no.2 | nes_1943.mid!
#     no.3 | nes_1943sab.mid!
#     no.4 | nes_1943-lev1.mid!
#     no.5 | nes_43pbos1.mid!
#     no.6 | nes_43pbos12.mid!
#     no.7 | nes_1943-lev3.mid!
#     no.8 | nes_1943-Lev3Win.mid!
#     no.9 | nes_1943lost.mid!
#     no.10 | nes_1943won.mid!
#     no.11 | nes_1943boss.mid!
#     no.12 | nes_1943boss1.mid!
#     no.13 | nes_1943BossWin.mid!
#     no.14 | nes_1999.mid!
#     no.15 | nes_3D_Worldrunner_Bonus.mid!
#     no.16 | nes_3D_Worldrunner_Boss.mid!
#     no.17 | nes_3D_Worldrunner_Main.mid!
#     no.18 | nes_720.mid!
#     no.19 | nes_Egypt.mid!
#     no.20 | nes_8_Eyes_-_Enterance.mid!
#     no.21 | nes_8_Eyes.mid!
#     no.22 | nes_8eyes-spain1.mid!
#     no.23 | nes_blob.mid!
#     no.24 | nes_blob_title.mid!
#     no.25 | nes_elmst.mid!
#     no.26 | nes_elm_street_metal.mid!
#     no.27 | nes_zzz.mid!
#     no.28 | nes_freddy%21.mid!
#     no.29 | nes_Nmoes1.mid!
#     no.30 | nes_nmoes2.mid!
#     no.31 | nes_nmoes3.mid!
#     no.32 | nes_attic.mid!
#     no.33 | nes_basement.mid!
#     no.34 | nes_wakeup%21%21.mid!
#     no.35 | nes_abadoxgo.mid!
#     no.36 | nes_Action52DamBusters.mid!
#     no.37 | nes_thrusters.mid!
#     no.38 | nes_megalonia.mid!
#     no.39 | nes_RocketjockA52.mid!
#     no.40 | nes_Nonhuman1.mid!
#     no.41 | nes_Star_Evil.mid!
#     no.42 | nes_Action52FuzzPower.mid!
#     no.43 | nes_lollipop.mid!
#     no.44 | nes_lollipop2.mid!
#     no.45 | nes_Illuminator.mid!
#     no.46 | nes_Action52CityofDoom.mid!
#     no.47 | nes_Action52BitsandPieces.mid!
#     no.48 | nes_Action52Cheetahmen.mid!
#     no.49 | nes_DarkForest.mid!
#     no.50 | nes_AdvislEggplant.mid!
#     no.51 | nes_Adventure_Island_Level_1.mid!
#     no.52 | nes_Adventureislandrock.mid!
#     no.53 | nes_Adventure_Island_Level_2.mid!
#     no.54 | nes_Adventure_Island_-_Level_2_-_Remix.mid!
#     no.55 | nes_Adventure_Island_-_Underworld.mid!
#     no.56 | nes_Adventure_Island_II-Bonus.mid!
#     no.57 | nes_Adventure_Island_II-Caves.mid!
#     no.58 | nes_Adventure_Island_II-Choose_an_Egg.mid!
#     no.59 | nes_Adventure_Island_II-Congratulations%21.mid!
#     no.60 | nes_Adventure_Island_II-Credits.mid!
#     no.61 | nes_Adventure_Island_II-Death.mid!
#     no.62 | nes_Adventure_Island_II-Desert.mid!
#     no.63 | nes_Adventure_Island_II-Eggplant.mid!
#     no.64 | nes_Adventure_Island_II-Game_Over.mid!
#     no.65 | nes_Adventure_Island_II-Goal.mid!
#     no.66 | nes_Adventure_Island_II-Ice_Caves.mid!
#     no.67 | nes_Adventure_Island_II-Island_Boss.mid!
#     no.68 | nes_Adventure_Island_II-Map_Screen.mid!
#     no.69 | nes_Adventure_Island_II-Over_the_Clouds.mid!
#     no.70 | nes_Adventure_Island_II-Overworld_1.mid!
#     no.71 | nes_Adventure_Island_II-Overworld_2_%28Re-upload%29.mid!
#     no.72 | nes_Adventure_Island_II-Overworld_3.mid!
#     no.73 | nes_Adventure_Island_II-Skip_This_Island.mid!
#     no.74 | nes_Adventure_Island_II-Snow_Summit_%28Version_2%29.mid!
#     no.75 | nes_Adventure_Island_II-Title_Screen.mid!
#     no.76 | nes_Adventure_Island_II-UnderwaterV2.mid!
#     no.77 | nes_Adventure_Island_II-Underworld_1.mid!
#     no.78 | nes_Adventure_Island_II-Underworld_2.mid!
#     no.79 | nes_Adventure_Island_II-Victory.mid!
#     no.80 | nes_A3_cave.mid!
#     no.81 | nes_AI3-Credits.mid!
#     no.82 | nes_AI3-FinalBoss.mid!
#     no.83 | nes_A3_over.mid!
#     no.84 | nes_AI3-Shipwreck.mid!
#     no.85 | nes_AI3-Thundercloud.mid!
#     no.86 | nes_A3_title.mid!
#     no.87 | nes_MKAUTO.mid!
#     no.88 | nes_MKMINE.mid!
#     no.89 | nes_MKHHOUSE.mid!
#     no.90 | nes_mkhaunted.mid!
#     no.91 | nes_MKWORLD.mid!
#     no.92 | nes_ADVMAP.mid!
#     no.93 | nes_MKPIRATE.mid!
#     no.94 | nes_MKSPACE.mid!
#     no.95 | nes_ADVSTORY.mid!
#     no.96 | nes_MKTITLE.mid!
#     no.97 | nes_ADVTITLE.mid!
#     no.98 | nes_Adventures_of_Bayou_Billy_BGM_A_Electric_Remix.mid!
#     no.99 | nes_abb-bgma.mid!
#     no.100 | nes_ABBBGM-B.mid!
#     no.101 | nes_AdventuresOfLolo-Stage_Music.mid!
#     no.102 | nes_Lolo.mid!
#     no.103 | nes_Xky_LoloStage.mid!
#     no.104 | nes_advlolo1_theme.mid!
#     no.105 | nes_Lolo1lvl.mid!
#     no.106 | nes_Pommy.mid!
#     no.107 | nes_lolo2ending.mid!
#     no.108 | nes_Lolo2clr.mid!
#     no.109 | nes_Lolo2lvl.mid!
#     no.110 | nes_Lolo2pw.mid!
#     no.111 | nes_LOLO3BOS.mid!
#     no.112 | nes_lolo3lev.mid!
#     no.113 | nes_Lolo3lvl.mid!
#     no.114 | nes_AiSenshiNicolBossTheme.mid!
#     no.115 | nes_AiSenshiNicolDungeon.mid!
#     no.116 | nes_AiSenshiNicolStages1and4.mid!
#     no.117 | nes_Enc.mid!
#     no.118 | nes_airfortress.mid!
#     no.119 | nes_AFintro.mid!
#     no.120 | nes_AFLanding.mid!
#     no.121 | nes_AFLevel_1.mid!
#     no.122 | nes_AFLevel_End.mid!
#     no.123 | nes_AFLevel_Intro.mid!
#     no.124 | nes_Inside.mid!
#     no.125 | nes_airwolf_title.mid!
#     no.126 | nes_Alfred_Chicken_Level_1.mid!
#     no.127 | nes_nes-alien3_level01.mid!
#     no.128 | nes_alien3sb.mid!
#     no.129 | nes_alphago.mid!
#     no.130 | nes_alphamis.mid!
#     no.131 | nes_Amagon-Area_Clear.mid!
#     no.132 | nes_Amagon-Boss.mid!
#     no.133 | nes_Amagon-Death.mid!
#     no.134 | nes_Amagon-Final_Victory.mid!
#     no.135 | nes_Amagon-Ending.mid!
#     no.136 | nes_Amagon-Final_Boss.mid!
#     no.137 | nes_Amagon-Start_2.mid!
#     no.138 | nes_Amagon-Super_Boss.mid!
#     no.139 | nes_Amagon-Title_2.mid!
#     no.140 | nes_amagonwrld1.mid!
#     no.141 | nes_Amagon-Zone_2_Jungle.mid!
#     no.142 | nes_Amagon-Zone_3_River.mid!
#     no.143 | nes_Amagon-Zone_4_Rain_Forest.mid!
#     no.144 | nes_Amagon-Zone_5_-_Rocky_Mountain.mid!
#     no.145 | nes_ANTARending_.mid!
#     no.146 | nes_ANTARLevel_Music.mid!
#     no.147 | nes_ANTARIntro.mid!
#     no.148 | nes_ANTARLevel_Complete.mid!
#     no.149 | nes_Anticipation5.mid!
#     no.150 | nes_Anticipation9.mid!
#     no.151 | nes_Anticipation4.mid!
#     no.152 | nes_Anticipation11.mid!
#     no.153 | nes_Anticipation6.mid!
#     no.154 | nes_Anticipation10.mid!
#     no.155 | nes_Anticipation2.mid!
#     no.156 | nes_Anticipation7.mid!
#     no.157 | nes_Anticipation.mid!
#     no.158 | nes_Anticipation12.mid!
#     no.159 | nes_Anticipation8.mid!
#     no.160 | nes_Anticipation3.mid!
#     no.161 | nes_ads_shop.mid!
#     no.162 | nes_archon_battle.mid!
#     no.163 | nes_archon_title.mid!
#     no.164 | nes_T_Rygar4.mid!
#     no.165 | nes_T_Ryga14.mid!
#     no.166 | nes_T_Rygar8.mid!
#     no.167 | nes_T_Rygar2.mid!
#     no.168 | nes_T_Rygar5.mid!
#     no.169 | nes_T_Ryga11.mid!
#     no.170 | nes_T_Ryga12.mid!
#     no.171 | nes_T_Rygar7.mid!
#     no.172 | nes_T_Ryga13.mid!
#     no.173 | nes_T_Rygar3.mid!
#     no.174 | nes_T_Rygar9.mid!
#     no.175 | nes_T_Rygar1.mid!
#     no.176 | nes_T_Ryga15.mid!
#     no.177 | nes_T_Ryga10.mid!
#     no.178 | nes_arkistas-opening.mid!
#     no.179 | nes_armadillo_casino.mid!
#     no.180 | nes_ADFV_-_Battle_Theme.mid!
#     no.181 | nes_T_ArumanaNoKiseki_Caverns.mid!
#     no.182 | nes_Astyanax1.mid!
#     no.183 | nes_Astyanax-Redwood.mid!
#     no.184 | nes_astyrem.mid!
#     no.185 | nes_Astyanax-Remlia.mid!
#     no.186 | nes_REMLIA.mid!
#     no.187 | nes_GREMLIA.mid!
#     no.188 | nes_Astyanax3.mid!
#     no.189 | nes_Astyanax2.mid!
#     no.190 | nes_anstyanintro.mid!
#     no.191 | nes_Athena-Boss.mid!
#     no.192 | nes_Athena-Over.mid!
#     no.193 | nes_Athena-Start.mid!
#     no.194 | nes_Athena-Cavern.mid!
#     no.195 | nes_Athena-Forest.mid!
#     no.196 | nes_Athena-Hell.mid!
#     no.197 | nes_Athena-Ice.mid!
#     no.198 | nes_Athena-Labyrinth.mid!
#     no.199 | nes_Athena-Sea.mid!
#     no.200 | nes_Athena-Sky.mid!
#     no.201 | nes_AotKT_Bomb_Disabled.mid!
#     no.202 | nes_AotKT_-_The_Secret_Stage.mid!
#     no.203 | nes_AotKT_TomatoFactory.mid!
#     no.204 | nes_BWings.mid!
#     no.205 | nes_B-wings_Stage.mid!
#     no.206 | nes_bttf-nes.mid!
#     no.207 | nes_bttf2go.mid!
#     no.208 | nes_bttf2.mid!
#     no.209 | nes_baddudes-stage2.mid!
#     no.210 | nes_baddudes_train.mid!
#     no.211 | nes_Balloon_Fight-Complete.mid!
#     no.212 | nes_Balloon_Fight_-_Game_Over_GS.mid!
#     no.213 | nes_balloon.mid!
#     no.214 | nes_Balloon_Fight_-_Main_Theme_%28Dancing_Balloon%21_remix%29.mid!
#     no.215 | nes_banana.mid!
#     no.216 | nes_Batmango.mid!
#     no.217 | nes_bm1-st1.mid!
#     no.218 | nes_T_Batman_Stage1-1.mid!
#     no.219 | nes_Batman_-_Stage1XG.mid!
#     no.220 | nes_Batman-_Level_2.mid!
#     no.221 | nes_T_Batman_Stage2-1.mid!
#     no.222 | nes_BatmanNESlvl3.mid!
#     no.223 | nes_BatmanNESlvl4.mid!
#     no.224 | nes_batman-fabric.mid!
#     no.225 | nes_btmnjstg.mid!
#     no.226 | nes_batmanreturn2.mid!
#     no.227 | nes_BmRoJ_Main_Theme-KM.mid!
#     no.228 | nes_batmanreturn.mid!
#     no.229 | nes_Batman2_-_GothamInDanger.mid!
#     no.230 | nes_Batman2_-_UrgentXG.mid!
#     no.231 | nes_palace2.mid!
#     no.232 | nes_olympus.mid!
#     no.233 | nes_arcadia.mid!
#     no.234 | nes_Arcadia_-_Green_Fields.mid!
#     no.235 | nes_Attica_-_Town_of_Elyseus.mid!
#     no.236 | nes_Tartarus_-_Battle_with_Hades.mid!
#     no.237 | nes_Battle_Of_Olympus_Phrygia_Slow_Remix.mid!
#     no.238 | nes_Crete_-_The_Island_Maze.mid!
#     no.239 | nes_Ending_Theme_-_Let%27s_Return.mid!
#     no.240 | nes_The_Underworld_%26_Hades_Castle.mid!
#     no.241 | nes_olymp_hero.mid!
#     no.242 | nes_olymp.mid!
#     no.243 | nes_olympus1.mid!
#     no.244 | nes_Laconia.mid!
#     no.245 | nes_Laconia_-_Where_Land_Ends.mid!
#     no.246 | nes_Laconia_2.mid!
#     no.247 | nes_The_Map_-_Face_your_destiny.mid!
#     no.248 | nes_olymp_2.mid!
#     no.249 | nes_palace3.mid!
#     no.250 | nes_peloponnes_-_dark_and_beautiful.mid!
#     no.251 | nes_Peloponnesus.mid!
#     no.252 | nes_Phitia_-_The_Golden_Apple.mid!
#     no.253 | nes_Phrygia.mid!
#     no.254 | nes_Phrygia_-_Searching_the_Moon_Ball.mid!
#     no.255 | nes_Phthia.mid!
#     no.256 | nes_Phithia.mid!
#     no.257 | nes_Ride_with_Pegasus_%26_Enter_your_Name.mid!
#     no.258 | nes_Snake_Pit.mid!
#     no.259 | nes_Battletoads_-_Boss.mid!
#     no.260 | nes_battletoads_level1.mid!
#     no.261 | nes_Ratrace.mid!
#     no.262 | nes_Clinger_Winger.mid!
#     no.263 | nes_The_Revolution.mid!
#     no.264 | nes_wookie.mid!

# %%
# !python3 gmvae.py -p build_dataset

# %%
# !python3 gmvae.py -p build_trio

# %%
# !python3 gmvae.py -p transfer_midi

# %%
# !python3 gmvae.py -p transfer_sequence_note
